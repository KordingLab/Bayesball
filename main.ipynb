# %% [markdown]
# # Setup

# %%
# OS, misc.
import os
from pathlib import Path
import pickle 
from tqdm import tqdm

# Data analysis
import pandas as pd
import numpy as np
import scipy.stats as stats
import statsmodels.api as sm
from statsmodels.sandbox.regression.predstd import wls_prediction_std

# Data scraping
import pybaseball
pybaseball.cache.enable()

# Plotting
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.image as mpimg
from matplotlib import colors, cm
import matplotlib.gridspec as gridspec
from matplotlib.patches import Rectangle

# %% [markdown]
# # Define helper functions
#
# The misc. helper functions are relatively straightforward, so instead of importing them as a module they are just defined in a separate `.py` file.

# %%
# %run -i "lib/0_helper_functions.py"

# %% [markdown]
# # Analyze Data
#
# The default is to load the data. If not, the data will be scraped from [Baseball Savant](https://baseballsavant.mlb.com/). Be forewarned, this takes a very long time!

# %%
# Either load data or gather using pybaseball
load_data = True

# Data path
data_path = Path("data/statcast_data_2015-2021_raw.pkl")

# If data does not exist download directly from baseball savant
if not data_path.exists():
    load_data = False

# Run data analysis file
# %run -i "lib/1_analyze_data.py"
# Out:
# Loading data...done.
# Cleaning up dataframe...done.
# Processing pitch data...
# 100%|██████████| 7/7 [00:02<00:00,  2.81it/s]
# Done.
# Performing regression for each pitcher ...
# 100%|██████████| 1881/1881 [00:40<00:00, 46.97it/s]

# %% [markdown]
# # Figure Parts
# The final figures were assembled in Inkscape. The individual data plots are made here. Some of the figures are not pretty until they are reorganized in the final figure in Inkscape (or vector program of your choosing).

# %% [markdown]
# ## Figure 1: Bayesball Story

# %%
# %run -i "lib/2_figure1.py"
# Out:
# /Users/justinbrantley/miniconda3/envs/bayesball/lib/python3.10/site-packages/scipy/stats/_distn_infrastructure.py:1870: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)

# %% [markdown]
# ## Figure 2: Main results

# %%
# %run -i "lib/3_figure2.py"

# %% [markdown]
# ## Figure 3: Pitch tipping

# %%
# %run -i "lib/4_figure3.py"

# %% [markdown]
# ## Figure 4: Knuckleball and Eephus

# %%
# %run -i "lib/5_figure4.py"
